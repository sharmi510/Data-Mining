# %% [markdown]
# <a href="https://colab.research.google.com/github/sharmi510/Data-Mining/blob/main/CMP7206%20Lab1%20Python%20Exercises%20Sharmila%2026152792.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CMP7206 · Lab 1 Python exercises
#
# Dr Mohamed Ihmeida
#
# Aligned with the procedural Python notebook. Run each cell in order. Write your solution in each blank code cell. The final task combines earlier ideas.

# %% [markdown]
# ## 1. Variables and data types
#
# Create variables for a dataset name, its number of rows, a missing-value percentage, and whether it has labels. Print each value and its type.

# %%
# Write your code here
dataset_name = "Financial Transactions Dataset"
number_of_rows = 35000
missing_value_percentage = 3.5
has_labels = True

# Print each value and its type
print(f"Dataset Name: {dataset_name}, Type: {type(dataset_name)}")
print(f"Number of Rows: {number_of_rows}, Type: {type(number_of_rows)}")
print(f"Missing-Value Percentage: {missing_value_percentage} Type: {type(missing_value_percentage)}")
print(f"Has Labels: {has_labels}, Type: {type(has_labels)}")
# Out:
# Dataset Name: Financial Transactions Dataset, Type: <class 'str'>
# Number of Rows: 35000, Type: <class 'int'>
# Missing-Value Percentage: 3.5 Type: <class 'float'>
# Has Labels: True, Type: <class 'bool'>

# %% [markdown]
# ## 2. Input and arithmetic
#
# Ask the user for the number of records before and after cleaning. Convert both inputs to integers. Print the number of records removed and the percentage retained, rounded to one decimal place. Assume the initial count is greater than zero.

# %%
# Write your code here
initial_records = int(input("Enter the number of records before cleaning: "))
cleaned_records = int(input("Enter the number of records after cleaning: "))

records_removed = initial_records - cleaned_records
percentage_retained = (cleaned_records / initial_records) * 100

print(f"Records removed: {records_removed}")
print(f"Percentage retained: {round(percentage_retained, 1)}%")
# Out:
# Enter the number of records before cleaning: 34
# Enter the number of records after cleaning: 55
# Records removed: -21
# Percentage retained: 161.8%

# %% [markdown]
# ## 3. Conditional statements
#
# Given `accuracy = 0.82`, print “Excellent” for values at least 0.90, “Good” for values at least 0.75, and “Needs improvement” otherwise. Try other values too.

# %%
# Write your code here
accuracy =  float(input("Enter accuracy: "))

if accuracy >= 0.90:
    print("Excellent")
elif accuracy >= 0.75:
    print("Good")
else:
    print("Needs improvement")
# Out:
# Enter accuracy: 0.95
# Excellent

# %% [markdown]
# ## 4. Logical operators
#
# Given `rows = 150` and `missing_percentage = 4`, print whether a dataset is ready for analysis. It is ready only when it has at least 100 rows AND less than 5% missing values.

# %%
# Write your code here
rows = 120
missing_percentage = 3

if rows >= 100 and missing_percentage < 5:
    print("Dataset is ready for analysis")
else:
    print("Dataset is not ready for analysis")
# Out:
# Dataset is ready for analysis

# %% [markdown]
# ## 5. For loops
#
# Given `daily_sales = [12, 15, 9, 20, 14]`, use a `for` loop to calculate the total without calling `sum()`. Print the total.

# %%
# Write your code here
daily_sales = [12, 15, 9, 20, 14]

total = 0

for sales in daily_sales:
    total = total + sales

print(f"Total sales: {total}")
# Out:
# Total sales: 70

# %% [markdown]
# ## 6. While loops
#
# Start with `remaining = 5`. Use a `while` loop to print 5 down to 1, decreasing the value each time. Print “Finished” at the end.

# %%
# Write your code here
remaining = 5

while remaining > 0:
    print(remaining)
    remaining -= 1

print("Finished")
# Out:
# 5
# 4
# 3
# 2
# 1
# Finished

# %% [markdown]
# ## 7. Functions
#
# Write a function `average_score(scores)` that returns the average of a non-empty list of scores. Call it with `[70, 80, 90]` and print the result.

# %%
# Write your code here
def average_score(scores):
    return sum(scores) / len(scores)

result = average_score([70, 80, 90])

print(f"Average score: {result}")
# Out:
# Average score: 80.0

# %% [markdown]
# ## 8. Lists and slicing
#
# Given `scores = [45, 67, 82, 91]`, append `75`, print the first three scores using a slice, then print how many scores there are.

# %%
# Write your code here
scores = [45, 67, 82, 91]

# Add 75 to the list
scores.append(75)

print(f"First three scores: {scores[:3]}")

print(f"Number of scores: {len(scores)}")
# Out:
# First three scores: [45, 67, 82]
# Number of scores: 5

# %% [markdown]
# ## 9. Tuples
#
# Create a tuple containing three feature names: `age`, `income`, and `spending`. Print the second feature and the total number of features.

# %%
# Write your code here
features = (("age", 24), ("income", 50000), ("spending", 10000))

print(f"Second feature: {features[1]}")

print(f"Total number of features: {len(features)}")
# Out:
# Second feature: ('income', 50000)
# Total number of features: 3

# %% [markdown]
# ## 10. Dictionaries
#
# Create a dictionary for a dataset with keys `name`, `rows`, and `columns`. Print its name, update its row count, add a `cleaned` key with value `True`, and print the whole dictionary.

# %%
# Write your code here
dataset = {
    "name": "Financial Transacations Dataset",
    "rows": 500,
    "columns": 10
}

print(f"Dataset name: {dataset['name']}")

dataset["rows"] = 600

dataset["cleaned"] = True

print(dataset)
# Out:
# Dataset name: Financial Transacations Dataset
# {'name': 'Financial Transacations Dataset', 'rows': 600, 'columns': 10, 'cleaned': True}

# %% [markdown]
# ## 11. Built-in functions
#
# Given `values = [-3, 8, 0, -5, 10]`, print the minimum, maximum, sum and number of values. Then use a loop and `abs()` to print each absolute value.

# %%
# Write your code here
values = [-3, 8, 0, -5, 10]

minimum = min(values)
maximum = max(values)
total = sum(values)
count = len(values)

print(f"Minimum: {minimum}")
print(f"Maximum: {maximum}")
print(f"Sum: {total}")
print(f"Number of values: {count}")

for value in values:
    print(abs(value))
# Out:
# Minimum: -5
# Maximum: 10
# Sum: 10
# Number of values: 5
# 3
# 8
# 0
# 5
# 10

# %% [markdown]
# ## 12. Nested data challenge
#
# Given the records below, use a loop to print the name of each student whose score is at least 50. Then calculate and print the mean score. Use only concepts covered in this lab.
#
# `students = [{"name": "Amina", "score": 72}, {"name": "Ben", "score": 45}, {"name": "Chen", "score": 83}]`

# %%
# Write your code here
students = [{"name": "Amina", "score": 72},
    {"name": "Ben", "score": 45},
    {"name": "Chen", "score": 83}]

for student in students:
    if student["score"] >= 50:
        print(f"{student['name']}")

# Calculate the mean score
total = 0

for student in students:
    total = total + student["score"]

mean_score = total / len(students)

print(f"Mean score: {round(mean_score, 1)}")
# Out:
# Amina
# Chen
# Mean score: 66.7
